# %%
import pandas as pd
import numpy as np
import pickle
from datetime import datetime



future_data = pd.read_csv("2025-season-fix.csv")


team_map = {
    'Alaves': 0, 'Las Palmas': 1, 'Real Sociedad': 2, 'Atletico Madrid': 3, 'Espanyol': 4,
    'Getafe': 5, 'Real Betis': 6, 'Real Madrid': 7, 'Villarreal': 8, 'Eibar': 9,
    'Celta Vigo': 10, 'Barcelona': 11, 'Malaga': 12, 'Deportivo La Coruna': 13,
    'Athletic Club': 14, 'Leganes': 15, 'Sevilla': 16, 'Valencia': 17, 'Levante': 18,
    'Girona': 19, 'Valladolid': 20, 'Huesca': 21, 'Rayo Vallecano': 22, 'Osasuna': 23,
    'Granada': 24, 'Mallorca': 25, 'Cadiz': 26, 'Elche': 27, 'Almeria': 28,
    'Real Oviedo': 29
}

def map_team(team):
    return team_map.get(team, len(team_map)+1)

# ------------------- Preprocessing -------------------

# Extract time components
future_data['Time'] = pd.to_datetime(future_data['Time'], format='%H:%M').dt.time
future_data['Time_dt'] = pd.to_datetime(future_data['Time'].astype(str), format='%H:%M:%S')
future_data['Hour'] = future_data['Time_dt'].dt.hour
future_data['Minute'] = future_data['Time_dt'].dt.minute
future_data['Minutes_Since_Midnight'] = future_data['Hour'] * 60 + future_data['Minute']

# Cyclical encoding of time
future_data['Time_Sin'] = np.sin(2 * np.pi * future_data['Minutes_Since_Midnight'] / 1440)
future_data['Time_Cos'] = np.cos(2 * np.pi * future_data['Minutes_Since_Midnight'] / 1440)

# Team binary encoding
future_data['Home_code'] = future_data['Home'].apply(map_team)
future_data['Away_code'] = future_data['Away'].apply(map_team)

def binary_encode(number, num_bits=5):
    return [int(bit) for bit in bin(number)[2:].zfill(num_bits)]

home_code_df = future_data['Home_code'].apply(lambda x: binary_encode(x)).apply(pd.Series)
away_code_df = future_data['Away_code'].apply(lambda x: binary_encode(x)).apply(pd.Series)

home_code_df.columns = [f'Home_code_{i}' for i in range(home_code_df.shape[1])]
away_code_df.columns = [f'Away_code_{i}' for i in range(away_code_df.shape[1])]


features_df = pd.concat([
    future_data,
    home_code_df,
    away_code_df
], axis=1)


model_inputs = features_df[[
    'Time_Sin', 'Time_Cos', 'Matchweek', 'Home_Pos',
    'Home_code_0', 'Home_code_1', 'Home_code_2', 'Home_code_3', 'Home_code_4',
    'xG_Home', 'xG_Away',
    'Away_code_0', 'Away_code_1', 'Away_code_2', 'Away_code_3', 'Away_code_4',
    'Away_Pos'
]]

# Rename to match training data column names
model_inputs = model_inputs.rename(columns={
    'Matchweek': 'Wk',
    'Home_Pos': 'Home Position',
    'Away_Pos': 'Away Position'
})

# ------------------- Load scaler and model -------------------

with open('scaler', 'rb') as file:
    scaler = pickle.load(file)

with open('model', 'rb') as file:
    model = pickle.load(file)

# Scale xG features
model_inputs[['xG_Home', 'xG_Away']] = scaler.transform(model_inputs[['xG_Home', 'xG_Away']])

# ------------------- Predict probabilities -------------------

probs = model.predict_proba(model_inputs)
home_win_probs = probs[:, 1]
home_not_win_probs = probs[:, 0]

# ------------------- Final Output -------------------

output_df = pd.DataFrame({
    'Matchweek': future_data['Matchweek'],
    'Home': future_data['Home'],
    'Away': future_data['Away'],
    'xG_Home': future_data['xG_Home'],
    'xG_Away': future_data['xG_Away'],
    'Home_Win_Probability': home_win_probs,
    'Home_Not_Win_Probability': home_not_win_probs
})


output_df[['Home_Win_Probability', 'Home_Not_Win_Probability']] = output_df[[
    'Home_Win_Probability', 'Home_Not_Win_Probability']].round(4)


for idx, row in output_df.iterrows():
    print(f"Matchweek {future_data.loc[idx, 'Matchweek']}")
    print(f"{row['Home']} vs {row['Away']}")
    print(f"{row['Home']} win probability: {round(row['Home_Win_Probability'] * 100, 2)}%")
    print(f"{row['Away']} win probability: {round(row['Home_Not_Win_Probability'] * 100, 2)}%\n")
# Out:
# Matchweek 1
# Girona vs Rayo Vallecano
# Girona win probability: 3.96%
# Rayo Vallecano win probability: 96.04%
#
# Matchweek 1
# Villarreal vs Oviedo
# Villarreal win probability: 58.93%
# Oviedo win probability: 41.07%
#
# Matchweek 1
# Mallorca vs Barcelona
# Mallorca win probability: 5.04%
# Barcelona win probability: 94.96%
#
# Matchweek 1
# Alavés vs Levante
# Alavés win probability: 30.25%
# Levante win probability: 69.75%
#
# Matchweek 1
# Valencia vs Real Sociedad
# Valencia win probability: 55.87%
# Real Sociedad win probability: 44.13%
#
# Matchweek 1
# Celta Vigo vs Getafe
# Celta Vigo win probability: 17.23%
# Getafe win probability: 82.77%
#
# Matchweek 1
# Athletic Club vs Sevilla
# Athletic Club win probability: 69.0%
# Sevilla win probability: 31.0%
#
# Matchweek 1
# Espanyol vs Atlético Madrid
# Espanyol win probability: 30.22%
# Atlético Madrid win probability: 69.78%
#
# Matchweek 1
# Elche vs Betis
# Elche win probability: 11.24%
# Betis win probability: 88.76%
#
# Matchweek 1
# Real Madrid vs Osasuna
# Real Madrid win probability: 58.07%
# Osasuna win probability: 41.93%
#
# Matchweek 2
# Betis vs Alavés
# Betis win probability: 42.6%
# Alavés win probability: 57.4%
#
# Matchweek 2
# Mallorca vs Celta Vigo
# Mallorca win probability: 27.65%
# Celta Vigo win probability: 72.35%
#
# Matchweek 2
# Atlético Madrid vs Elche
# Atlético Madrid win probability: 47.9%
# Elche win probability: 52.1%
#
# Matchweek 2
# Levante vs Barcelona
# Levante win probability: 20.02%
# Barcelona win probability: 79.98%
#
# Matchweek 2
# Osasuna vs Valencia
# Osasuna win probability: 36.38%
# Valencia win probability: 63.62%
#
# Matchweek 2
# Real Sociedad vs Espanyol
# Real Sociedad win probability: 34.73%
# Espanyol win probability: 65.27%
#
# Matchweek 2
# Villarreal vs Girona
# Villarreal win probability: 65.67%
# Girona win probability: 34.33%
#
# Matchweek 2
# Oviedo vs Real Madrid
# Oviedo win probability: 2.87%
# Real Madrid win probability: 97.13%
#
# Matchweek 2
# Athletic Club vs Rayo Vallecano
# Athletic Club win probability: 46.9%
# Rayo Vallecano win probability: 53.1%
#
# Matchweek 2
# Sevilla vs Getafe
# Sevilla win probability: 17.91%
# Getafe win probability: 82.09%
#
# Matchweek 3
# Elche vs Levante
# Elche win probability: 42.03%
# Levante win probability: 57.97%
#
# Matchweek 3
# Valencia vs Getafe
# Valencia win probability: 33.72%
# Getafe win probability: 66.28%
#
# Matchweek 3
# Alavés vs Atlético Madrid
# Alavés win probability: 27.64%
# Atlético Madrid win probability: 72.36%
#
# Matchweek 3
# Oviedo vs Real Sociedad
# Oviedo win probability: 13.67%
# Real Sociedad win probability: 86.33%
#
# Matchweek 3
# Girona vs Sevilla
# Girona win probability: 56.54%
# Sevilla win probability: 43.46%
#
# Matchweek 3
# Real Madrid vs Mallorca
# Real Madrid win probability: 75.85%
# Mallorca win probability: 24.15%
#
# Matchweek 3
# Celta Vigo vs Villarreal
# Celta Vigo win probability: 27.18%
# Villarreal win probability: 72.82%
#
# Matchweek 3
# Betis vs Athletic Club
# Betis win probability: 18.82%
# Athletic Club win probability: 81.18%
#
# Matchweek 3
# Espanyol vs Osasuna
# Espanyol win probability: 22.45%
# Osasuna win probability: 77.55%
#
# Matchweek 3
# Rayo Vallecano vs Barcelona
# Rayo Vallecano win probability: 22.42%
# Barcelona win probability: 77.58%
#
# Matchweek 4
# Sevilla vs Elche
# Sevilla win probability: 14.02%
# Elche win probability: 85.98%
#
# Matchweek 4
# Getafe vs Oviedo
# Getafe win probability: 49.94%
# Oviedo win probability: 50.06%
#
# Matchweek 4
# Real Sociedad vs Real Madrid
# Real Sociedad win probability: 20.58%
# Real Madrid win probability: 79.42%
#
# Matchweek 4
# Athletic Club vs Alavés
# Athletic Club win probability: 52.15%
# Alavés win probability: 47.85%
#
# Matchweek 4
# Atlético Madrid vs Villarreal
# Atlético Madrid win probability: 26.13%
# Villarreal win probability: 73.87%
#
# Matchweek 4
# Celta Vigo vs Girona
# Celta Vigo win probability: 73.19%
# Girona win probability: 26.81%
#
# Matchweek 4
# Levante vs Betis
# Levante win probability: 9.11%
# Betis win probability: 90.89%
#
# Matchweek 4
# Osasuna vs Rayo Vallecano
# Osasuna win probability: 40.79%
# Rayo Vallecano win probability: 59.21%
#
# Matchweek 4
# Barcelona vs Valencia
# Barcelona win probability: 96.12%
# Valencia win probability: 3.88%
#
# Matchweek 4
# Espanyol vs Mallorca
# Espanyol win probability: 49.1%
# Mallorca win probability: 50.9%
#
# Matchweek 5
# Betis vs Real Sociedad
# Betis win probability: 64.05%
# Real Sociedad win probability: 35.95%
#
# Matchweek 5
# Girona vs Levante
# Girona win probability: 6.56%
# Levante win probability: 93.44%
#
# Matchweek 5
# Real Madrid vs Espanyol
# Real Madrid win probability: 47.75%
# Espanyol win probability: 52.25%
#
# Matchweek 5
# Villarreal vs Osasuna
# Villarreal win probability: 38.03%
# Osasuna win probability: 61.97%
#
# Matchweek 5
# Alavés vs Sevilla
# Alavés win probability: 44.27%
# Sevilla win probability: 55.73%
#
# Matchweek 5
# Valencia vs Athletic Club
# Valencia win probability: 57.45%
# Athletic Club win probability: 42.55%
#
# Matchweek 5
# Rayo Vallecano vs Celta Vigo
# Rayo Vallecano win probability: 36.62%
# Celta Vigo win probability: 63.38%
#
# Matchweek 5
# Mallorca vs Atlético Madrid
# Mallorca win probability: 7.16%
# Atlético Madrid win probability: 92.84%
#
# Matchweek 5
# Elche vs Oviedo
# Elche win probability: 51.06%
# Oviedo win probability: 48.94%
#
# Matchweek 5
# Barcelona vs Getafe
# Barcelona win probability: 75.05%
# Getafe win probability: 24.95%
#
# Matchweek 6
# Celta Vigo vs Betis
# Celta Vigo win probability: 34.25%
# Betis win probability: 65.75%
