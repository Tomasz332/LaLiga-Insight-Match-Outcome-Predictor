# %%
import pandas as pd

# %%
year = 2006

url = f'https://www.transfermarkt.com/laliga/gesamtspielplan/wettbewerb/ES1?saison_id={year}&spieltagVon=1&spieltagBis=38'
filename = f'laliga_fixtures_{year}_{year + 1 % 100}.csv'

# url = 'https://www.transfermarkt.com/laliga/gesamtspielplan/wettbewerb/ES1?saison_id=2019&spieltagVon=1&spieltagBis=38'
# filename = 'laliga_fixtures_2019_20.csv'

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

URL = url
HEADERS = {"User-Agent": "Mozilla/5.0"}

def scrape_laliga_fixtures(url):
    response = requests.get(url, headers=HEADERS)
    response.raise_for_status()
    soup = BeautifulSoup(response.text, "html.parser")

    all_matches = []

    # Each Matchday is inside a div with class "box"
    for box in soup.select("div.box"):
        matchday_header = box.select_one(".content-box-headline")
        if not matchday_header:
            continue
        matchday = matchday_header.get_text(strip=True)

        # Each row of matches is in <tr>, skipping those that are just time separators
        for row in box.select("tbody tr"):
            # Skip rows without actual match (like "bg_blau_20" which are just separators)
            if "bg_blau_20" in row.get("class", []):
                continue

            cells = row.find_all("td")
            if len(cells) < 7:
                continue

            date = cells[0].get_text(strip=True)
            time = cells[1].get_text(strip=True)
            home_team = cells[2].get_text(" ", strip=True)
            result = cells[4].get_text(strip=True)
            away_team = cells[6].get_text(" ", strip=True)

            match_data = {
                "Matchday": matchday,
                "Date": date,
                "Time": time,
                "Home": home_team,
                "Result": result,
                "Away": away_team
            }
            all_matches.append(match_data)

    return pd.DataFrame(all_matches)


if __name__ == "__main__":
    df = scrape_laliga_fixtures(URL)
    print(df.head(20))  # show first 20 matches
    df.to_csv(filename, index=False)
# Out:
#       Matchday        Date      Time                 Home Result  \
# 0   1.Matchday  Sat8/26/06  10:00 PM             Valencia    2:1
# 1   1.Matchday  Sun8/27/06   7:00 PM             Espanyol    0:1
# 2   1.Matchday                             Dep. La Coruña    3:2
# 3   1.Matchday                                 CA Osasuna    0:2
# 4   1.Matchday                                Real Madrid    0:0
# 5   1.Matchday                               Recr. Huelva    1:1
# 6   1.Matchday                                     Racing    0:1
# 7   1.Matchday               9:00 PM        Athletic Club    1:1
# 8   1.Matchday  Mon8/28/06   9:00 PM        Celta de Vigo    2:3
# 9   1.Matchday  Tue8/29/06   9:00 PM           Sevilla FC    4:0
# 10  2.Matchday   Sat9/9/06   8:00 PM       (4.) Barcelona    3:0
# 11  2.Matchday              10:00 PM        (6.) Atlético    0:1
# 12  2.Matchday  Sun9/10/06   7:00 PM     (16.) Real Betis    3:0
# 13  2.Matchday                                (2.) Getafe    1:0
# 14  2.Matchday                             (7.) Gimnàstic    1:2
# 15  2.Matchday                              (20.) Levante    1:4
# 16  2.Matchday                          (9.) RCD Mallorca    0:0
# 17  2.Matchday                        (10.) Real Sociedad    1:3
# 18  2.Matchday                           (12.) Villarreal    0:1
# 19  2.Matchday               9:00 PM  (15.) Real Zaragoza    3:0
#
#                    Away
# 0            Real Betis
# 1             Gimnàstic
# 2         Real Zaragoza
# 3                Getafe
# 4            Villarreal
# 5          RCD Mallorca
# 6              Atlético
# 7         Real Sociedad
# 8             Barcelona
# 9               Levante
# 10     CA Osasuna (19.)
# 11        Valencia (5.)
# 12   Athletic Club (8.)
# 13         Racing (18.)
# 14  Celta de Vigo (14.)
# 15    Real Madrid (13.)
# 16  Dep. La Coruña (3.)
# 17      Sevilla FC (1.)
# 18   Recr. Huelva (11.)
# 19       Espanyol (17.)

# %%
df
# Out:
#         Matchday        Date      Time               Home Result  \
# 0     1.Matchday  Sat8/26/06  10:00 PM           Valencia    2:1
# 1     1.Matchday  Sun8/27/06   7:00 PM           Espanyol    0:1
# 2     1.Matchday                           Dep. La Coruña    3:2
# 3     1.Matchday                               CA Osasuna    0:2
# 4     1.Matchday                              Real Madrid    0:0
# ..           ...         ...       ...                ...    ...
# 375  38.Matchday               9:00 PM    (20.) Gimnàstic    1:5
# 376  38.Matchday                         (13.) CA Osasuna    1:2
# 377  38.Matchday                         (1.) Real Madrid    3:1
# 378  38.Matchday                        (8.) Recr. Huelva    1:1
# 379  38.Matchday                          (3.) Sevilla FC    0:1
#
#                    Away
# 0            Real Betis
# 1             Gimnàstic
# 2         Real Zaragoza
# 3                Getafe
# 4            Villarreal
# ..                  ...
# 375      Barcelona (2.)
# 376       Atlético (7.)
# 377  RCD Mallorca (11.)
# 378  Real Zaragoza (5.)
# 379     Villarreal (6.)
#
# [380 rows x 6 columns]

# %%
df_name = pd.read_html('https://fbref.com/en/comps/12/2024-2025/schedule/2024-2025-La-Liga-Scores-and-Fixtures'
                       , attrs={"id": "sched_2024-2025_12_1"})[0]

# %%
df_name
# Out:
#        Wk  Day        Date   Time           Home   xG Score  xG.1  \
# 0     1.0  Thu  2024-08-15  19:00  Athletic Club  0.3   1–1   0.8
# 1     1.0  Thu  2024-08-15  21:30          Betis  1.4   1–1   1.6
# 2     1.0  Fri  2024-08-16  19:00     Celta Vigo  0.8   2–1   1.6
# 3     1.0  Fri  2024-08-16  20:30     Las Palmas  1.4   2–2   1.8
# 4     1.0  Sat  2024-08-17  19:00        Osasuna  1.7   1–1   1.0
# ..    ...  ...         ...    ...            ...  ...   ...   ...
# 421  38.0  Sat  2025-05-24  21:00         Alavés  2.0   1–1   1.6
# 422  38.0  Sat  2025-05-24  21:00         Getafe  0.4   1–2   1.5
# 423  38.0  Sun  2025-05-25  14:00         Girona  0.0   0–4   2.7
# 424  38.0  Sun  2025-05-25  16:15     Villarreal  1.1   4–2   1.5
# 425  38.0  Sun  2025-05-25  21:00  Athletic Club  1.2   0–3   3.5
#
#                 Away  Attendance                          Venue  \
# 0             Getafe     47845.0                      San Mamés
# 1             Girona     54084.0      Estadio Benito Villamarín
# 2             Alavés     22477.0        Estadio Abanca Balaídos
# 3            Sevilla     24843.0        Estadio de Gran Canaria
# 4            Leganés     19561.0               Estadio El Sadar
# ..               ...         ...                            ...
# 421          Osasuna     19274.0        Estadio de Mendizorroza
# 422       Celta Vigo     12862.0         Coliseum Alfonso Pérez
# 423  Atlético Madrid     11546.0  Estadi Municipal de Montilivi
# 424          Sevilla     17758.0         Estadio de la Cerámica
# 425        Barcelona     50231.0                      San Mamés
#
#                       Referee  Match Report  Notes
# 0             Alejandro Muñíz  Match Report    NaN
# 1    Miguel Ángel Ortiz Arias  Match Report    NaN
# 2          Alejandro Quintero  Match Report    NaN
# 3         Francisco Hernández  Match Report    NaN
# 4                 Juan Pulido  Match Report    NaN
# ..                        ...           ...    ...
# 421          Guillermo Cuadra  Match Report    NaN
# 422             Juan Martínez  Match Report    NaN
# 423                 Jesús Gil  Match Report    NaN
# 424           Javier Alberola  Match Report    NaN
# 425            Pablo González  Match Report    NaN
#
# [426 rows x 14 columns]

# %%
df_name['Wk'].isnull().sum()
# Out:
# np.int64(46)

# %%
df_name = df_name.dropna(subset=['Wk'])

# %%
df_name.shape
# Out:
# (380, 14)
