# %% [markdown]
# # Concataning Dataframes - LaLiga

# %% [markdown]
# ## Importing libraries

# %%
import pandas as pd
import numpy as np
import re
from datetime import datetime

# %% [markdown]
# ## Load Data

# %%
s1718 = pd.read_csv('laliga_fixtures_2017_2018.csv')
s1819 = pd.read_csv('laliga_fixtures_2018_2019.csv')
s1920 = pd.read_csv('laliga_fixtures_2019_2020.csv')
s2021 = pd.read_csv('laliga_fixtures_2020_2021.csv')
s2122 = pd.read_csv('laliga_fixtures_2021_2022.csv')
s2223 = pd.read_csv('laliga_fixtures_2022_2023.csv')
s2324 = pd.read_csv('laliga_fixtures_2023_2024.csv')
s2425 = pd.read_csv('laliga_fixtures_2024_2025.csv')

# %%
s1718.head()
# Out:
#      Matchday        Date      Time           Home Result           Away
# 0  1.Matchday  Fri8/18/17   8:15 PM     CD Leganés   1:00         Alavés
# 1  1.Matchday         NaN  10:15 PM       Valencia   1:00  UD Las Palmas
# 2  1.Matchday  Sat8/19/17   6:15 PM  Celta de Vigo   2:03  Real Sociedad
# 3  1.Matchday         NaN   8:15 PM         Girona   2:02       Atlético
# 4  1.Matchday         NaN  10:15 PM     Sevilla FC   1:01       Espanyol

# %%
s1819.head()
# Out:
#      Matchday        Date      Time           Home Result             Away
# 0  1.Matchday  Fri8/17/18   8:15 PM         Girona    0:0  Real Valladolid
# 1  1.Matchday         NaN  10:15 PM     Real Betis    0:3          Levante
# 2  1.Matchday  Sat8/18/18   6:15 PM  Celta de Vigo    1:1         Espanyol
# 3  1.Matchday         NaN   8:15 PM     Villarreal    1:2    Real Sociedad
# 4  1.Matchday         NaN  10:15 PM      Barcelona    3:0           Alavés

# %%
s1718['Season'] = '2017-2018'
s1819['Season'] = '2018-2019'
s1920['Season'] = '2019-2020'
s2021['Season'] = '2020-2021'
s2122['Season'] = '2021-2022'
s2223['Season'] = '2022-2023'
s2324['Season'] = '2023-2024'
s2425['Season'] = '2024-2025'

# %%
all_seasons_df = pd.concat([
    s2425, s2324, s2223, s2122, s2021, s1920, s1819, s1718
], ignore_index=True)

# %%
all_seasons_df
# Out:
#          Matchday        Date      Time                 Home Result  \
# 0      1.Matchday  Thu8/15/24   7:00 PM        Athletic Club    1:1
# 1      1.Matchday         NaN   9:30 PM           Real Betis    1:1
# 2      1.Matchday  Fri8/16/24   7:00 PM        Celta de Vigo    2:1
# 3      1.Matchday         NaN   9:30 PM        UD Las Palmas    2:2
# 4      1.Matchday  Sat8/17/24   7:00 PM           CA Osasuna    1:1
# ...           ...         ...       ...                  ...    ...
# 3035  38.Matchday         NaN   8:45 PM      (5.) Villarreal   2:02
# 3036  38.Matchday  Sun5/20/18  12:00 PM        (4.) Valencia   2:01
# 3037  38.Matchday         NaN   4:15 PM  (16.) Athletic Club   0:01
# 3038  38.Matchday         NaN   6:30 PM        (2.) Atlético   2:02
# 3039  38.Matchday         NaN   8:45 PM       (1.) Barcelona   1:00
#
#                       Away     Season
# 0                   Getafe  2024-2025
# 1                   Girona  2024-2025
# 2                   Alavés  2024-2025
# 3               Sevilla FC  2024-2025
# 4               CD Leganés  2024-2025
# ...                    ...        ...
# 3035      Real Madrid (3.)  2017-2018
# 3036  Dep. La Coruña (18.)  2017-2018
# 3037        Espanyol (13.)  2017-2018
# 3038         SD Eibar (9.)  2017-2018
# 3039   Real Sociedad (10.)  2017-2018
#
# [3040 rows x 7 columns]

# %%
all_seasons_df['Home'].unique()
# Out:
# array(['Athletic Club', 'Real Betis', 'Celta de Vigo', 'UD Las Palmas',
#        'CA Osasuna', 'Valencia', 'Real Sociedad', 'RCD Mallorca',
#        'Real Valladolid', 'Villarreal', '(2.) Celta de Vigo',
#        '(6.) Sevilla FC', '(11.) CA Osasuna', '(1.) Barcelona',
#        '(13.) Getafe', '(20.) Espanyol', '(9.) Real Madrid',
#        '(16.) CD Leganés', '(18.) Alavés', '(5.) Atlético',
#        '(5.) Villarreal', '(17.) RCD Mallorca', '(8.) Rayo Vallecano',
#        '(15.) Athletic Club', '(10.) Real Valladolid',
#        '(9.) Real Sociedad', '(3.) Atlético', '(18.) Girona',
#        '(14.) UD Las Palmas', '(11.) Real Betis', '(9.) Athletic Club',
#        '(19.) Espanyol', '(20.) Valencia', '(7.) CD Leganés',
#        '(10.) Alavés', '(13.) CA Osasuna', '(16.) Sevilla FC',
#        '(17.) Getafe', '(5.) Real Madrid', '(10.) Real Betis',
#        '(9.) RCD Mallorca', '(16.) Espanyol', '(19.) Sevilla FC',
#        '(14.) Real Sociedad', '(8.) Celta de Vigo', '(5.) Girona',
#        '(18.) UD Las Palmas', '(13.) Rayo Vallecano', '(11.) Alavés',
#        '(17.) Real Valladolid', '(12.) CA Osasuna', '(3.) Real Madrid',
#        '(18.) Getafe', '(10.) Athletic Club', '(4.) Villarreal',
#        '(9.) Rayo Vallecano', '(6.) Real Betis', '(14.) CD Leganés',
#        '(15.) Sevilla FC', '(19.) Valencia', '(2.) Real Madrid',
#        '(12.) Girona', '(13.) Espanyol', '(20.) UD Las Palmas',
#        '(18.) Real Valladolid', '(19.) Getafe', '(16.) Real Sociedad',
#        '(6.) CA Osasuna', '(10.) Celta de Vigo', '(5.) Athletic Club',
#        '(17.) Espanyol', '(15.) Getafe', '(19.) Real Valladolid',
#        '(13.) Sevilla FC', '(14.) Alavés', '(6.) Athletic Club',
#        '(5.) CA Osasuna', '(10.) Girona', '(9.) Celta de Vigo',
#        '(7.) RCD Mallorca', '(18.) Valencia', '(14.) Espanyol',
#        '(19.) UD Las Palmas', '(17.) CD Leganés', '(16.) Getafe',
#        '(7.) Real Betis', '(11.) Real Sociedad', '(6.) RCD Mallorca',
#        '(17.) Alavés', '(8.) CA Osasuna', '(13.) Girona', '(4.) Atlético',
#        '(10.) Sevilla FC', '(11.) Celta de Vigo', '(3.) Villarreal',
#        '(15.) CD Leganés', '(8.) RCD Mallorca', '(16.) UD Las Palmas',
#        '(12.) Celta de Vigo', '(16.) Alavés', '(20.) Real Valladolid',
#        '(10.) Real Sociedad', '(12.) Sevilla FC', '(15.) UD Las Palmas',
#        '(8.) Girona', '(7.) CA Osasuna', '(18.) Espanyol',
#        '(12.) Rayo Vallecano', '(8.) Real Sociedad', '(2.) Barcelona',
#        '(13.) Celta de Vigo', '(3.) Barcelona', '(1.) Real Madrid',
#        '(9.) Real Betis', '(4.) Athletic Club', '(14.) Rayo Vallecano',
#        '(12.) UD Las Palmas', '(2.) Atlético', '(7.) Real Sociedad',
#        '(14.) Getafe', '(9.) Girona', '(6.) Rayo Vallecano',
#        '(7.) Girona', '(9.) CA Osasuna', '(14.) Celta de Vigo',
#        '(19.) Alavés', '(17.) UD Las Palmas', '(15.) Espanyol',
#        '(8.) Sevilla FC', '(14.) CA Osasuna', '(12.) Real Sociedad',
#        '(11.) Getafe', '(16.) Valencia', '(11.) Sevilla FC',
#        '(18.) CD Leganés', '(14.) Valencia', '(7.) Celta de Vigo',
#        '(10.) Rayo Vallecano', '(14.) Sevilla FC', '(16.) Girona',
#        '(12.) Getafe', '(19.) CD Leganés', '(11.) Rayo Vallecano',
#        '(12.) Valencia', '(15.) Girona', '(10.) CA Osasuna',
#        '(11.) Valencia', '(10.) RCD Mallorca', 'UD Almería', 'Sevilla FC',
#        'Getafe', 'Cádiz CF', 'Atlético', '(11.) RCD Mallorca',
#        '(6.) Valencia', '(19.) UD Almería', '(2.) CA Osasuna',
#        '(12.) Barcelona', '(5.) Real Betis', '(17.) Granada CF',
#        '(16.) Celta de Vigo', '(12.) Cádiz CF', '(19.) Granada CF',
#        '(18.) Sevilla FC', '(11.) Villarreal', '(3.) Valencia',
#        '(2.) Rayo Vallecano', '(10.) Cádiz CF', '(3.) Girona',
#        '(4.) Barcelona', '(15.) Villarreal', '(20.) Sevilla FC',
#        '(16.) Granada CF', '(20.) UD Almería', '(7.) Rayo Vallecano',
#        '(17.) Sevilla FC', '(16.) RCD Mallorca', '(12.) Villarreal',
#        '(9.) Cádiz CF', '(18.) Celta de Vigo', '(1.) Girona',
#        '(6.) Real Sociedad', '(15.) Alavés', '(13.) Villarreal',
#        '(10.) UD Las Palmas', '(16.) Villarreal', '(9.) Valencia',
#        '(15.) Cádiz CF', '(1.) Atlético', '(5.) Real Sociedad',
#        '(14.) Villarreal', '(16.) Cádiz CF', '(11.) UD Las Palmas',
#        '(2.) Girona', '(9.) Getafe', '(13.) Alavés', '(8.) UD Las Palmas',
#        '(15.) RCD Mallorca', '(8.) Getafe', '(10.) Valencia',
#        '(9.) UD Las Palmas', '(14.) RCD Mallorca', '(18.) Cádiz CF',
#        '(8.) Valencia', '(10.) Getafe', '(17.) Celta de Vigo',
#        '(12.) Alavés', '(16.) Rayo Vallecano', '(7.) Valencia',
#        '(9.) Villarreal', '(8.) Real Betis', '(13.) UD Las Palmas',
#        '(15.) Rayo Vallecano', '(8.) Villarreal', 'Barcelona',
#        '(9.) Espanyol', '(13.) RCD Mallorca', '(11.) Athletic Club',
#        '(18.) Elche CF', '(17.) Girona', '(3.) Real Betis',
#        '(17.) Elche CF', '(13.) UD Almería', '(20.) Getafe',
#        '(5.) Barcelona', '(19.) Cádiz CF', '(20.) Cádiz CF',
#        '(7.) Atlético', '(4.) Real Betis', '(4.) CA Osasuna',
#        '(11.) Girona', '(18.) UD Almería', '(15.) Real Valladolid',
#        '(20.) Elche CF', '(14.) Girona', '(12.) RCD Mallorca',
#        '(3.) Athletic Club', '(11.) Real Valladolid', '(15.) UD Almería',
#        '(4.) Real Sociedad', '(7.) Athletic Club',
#        '(12.) Real Valladolid', '(3.) Real Sociedad', '(7.) Villarreal',
#        '(14.) UD Almería', '(8.) Athletic Club', '(17.) Valencia',
#        '(13.) Real Valladolid', '(6.) Villarreal', '(17.) UD Almería',
#        '(14.) Real Valladolid', '(16.) Real Valladolid', '(14.) Cádiz CF',
#        '(17.) Cádiz CF', '(13.) Valencia', 'Alavés', 'Elche CF',
#        '(12.) Granada CF', '(18.) Real Sociedad', '(8.) Levante',
#        '(5.) Valencia', '(12.) Real Betis', '(8.) Cádiz CF',
#        '(20.) Rayo Vallecano', '(13.) Levante', '(2.) Sevilla FC',
#        '(11.) Elche CF', '(20.) Alavés', '(2.) Valencia', '(15.) Levante',
#        '(4.) Sevilla FC', '(8.) Barcelona', '(16.) Elche CF',
#        '(18.) Granada CF', '(18.) Levante', '(14.) Elche CF',
#        '(3.) Sevilla FC', '(6.) Barcelona', '(12.) Espanyol',
#        '(10.) Villarreal', '(19.) Levante', '(15.) Elche CF',
#        '(9.) Barcelona', '(2.) Real Sociedad', '(15.) Celta de Vigo',
#        '(14.) Granada CF', '(15.) Granada CF', '(7.) Barcelona',
#        '(20.) Levante', '(11.) Espanyol', '(12.) Athletic Club',
#        '(13.) Granada CF', '(6.) Atlético', '(5.) Rayo Vallecano',
#        '(13.) Elche CF', '(18.) RCD Mallorca', 'SD Eibar', 'Granada CF',
#        'Real Madrid', '(11.) SD Huesca', '(5.) Granada CF',
#        '(18.) Athletic Club', '(14.) SD Eibar', '(17.) SD Huesca',
#        '(18.) SD Eibar', '(14.) Athletic Club', '(6.) Granada CF',
#        '(16.) CA Osasuna', '(4.) Granada CF', '(16.) SD Eibar',
#        '(19.) Athletic Club', '(15.) SD Huesca', '(7.) Sevilla FC',
#        '(13.) SD Eibar', '(16.) Athletic Club', '(2.) Granada CF',
#        '(12.) Elche CF', '(19.) SD Huesca', '(17.) Levante',
#        '(7.) Cádiz CF', '(20.) Celta de Vigo', '(7.) Granada CF',
#        '(15.) Valencia', '(20.) SD Huesca', '(10.) Elche CF',
#        '(20.) CA Osasuna', '(11.) SD Eibar', '(14.) Levante',
#        '(13.) Athletic Club', '(5.) Sevilla FC', '(19.) CA Osasuna',
#        '(12.) Levante', '(11.) Cádiz CF', '(15.) SD Eibar',
#        '(10.) Levante', '(9.) Levante', '(19.) Elche CF',
#        '(17.) CA Osasuna', '(17.) SD Eibar', '(9.) Granada CF',
#        '(11.) Levante', '(19.) SD Eibar', '(8.) Granada CF',
#        '(18.) SD Huesca', '(20.) SD Eibar', '(13.) Cádiz CF',
#        '(10.) Granada CF', 'CD Leganés', 'Espanyol',
#        '(19.) Celta de Vigo', '(7.) Alavés', '(4.) RCD Mallorca',
#        '(15.) Barcelona', '(1.) Sevilla FC', '(20.) Real Betis',
#        '(20.) CD Leganés', '(11.) Barcelona', '(15.) Real Betis',
#        '(16.) Real Betis', '(19.) RCD Mallorca', '(3.) Granada CF',
#        '(17.) Real Betis', '(7.) Getafe', '(4.) Getafe', '(6.) Getafe',
#        '(11.) Granada CF', '(13.) Real Betis', '(5.) Getafe',
#        '(3.) Getafe', '(14.) Real Betis', 'Girona', 'Rayo Vallecano',
#        '(8.) Atlético', '(10.) Espanyol', '(3.) Levante',
#        '(17.) Villarreal', '(6.) Celta de Vigo', '(14.) SD Huesca',
#        '(12.) Atlético', '(5.) Celta de Vigo', '(9.) Sevilla FC',
#        '(3.) Alavés', '(17.) Rayo Vallecano', '(6.) Alavés',
#        '(9.) Real Valladolid', '(7.) Espanyol', '(19.) Rayo Vallecano',
#        '(12.) SD Eibar', '(6.) Real Valladolid', '(17.) Athletic Club',
#        '(2.) Alavés', '(5.) Espanyol', '(6.) Levante',
#        '(8.) Real Valladolid', '(5.) Alavés', '(6.) Real Madrid',
#        '(4.) Alavés', '(4.) Real Madrid', '(15.) Real Sociedad',
#        '(18.) Villarreal', '(13.) Real Sociedad', '(19.) Villarreal',
#        '(18.) Rayo Vallecano', '(13.) CD Leganés', '(10.) SD Eibar',
#        '(9.) SD Eibar', '(12.) CD Leganés', '(11.) CD Leganés',
#        '(8.) Alavés', '(16.) Levante', 'Dep. La Coruña', 'Levante',
#        'Málaga CF', '(19.) Real Betis', '(7.) Levante', '(4.) SD Eibar',
#        '(3.) CD Leganés', '(15.) Dep. La Coruña', '(17.) Málaga CF',
#        '(18.) Dep. La Coruña', '(20.) Málaga CF', '(4.) Valencia',
#        '(6.) CD Leganés', '(14.) Dep. La Coruña', '(16.) Dep. La Coruña',
#        '(9.) CD Leganés', '(19.) Málaga CF', '(17.) Dep. La Coruña',
#        '(8.) CD Leganés', '(8.) SD Eibar', '(7.) SD Eibar',
#        '(19.) Dep. La Coruña'], dtype=object)

# %% [markdown]
# ## Extracting Home Positions

# %%
all_seasons_df['Home Position'] = (
    all_seasons_df['Home']
    .str.extract(r'\((\d+)\.\)')   # updated to handle the period after the number
    .fillna(0)
    .astype(int)
)

# %%
all_seasons_df
# Out:
#          Matchday        Date      Time                 Home Result  \
# 0      1.Matchday  Thu8/15/24   7:00 PM        Athletic Club    1:1
# 1      1.Matchday         NaN   9:30 PM           Real Betis    1:1
# 2      1.Matchday  Fri8/16/24   7:00 PM        Celta de Vigo    2:1
# 3      1.Matchday         NaN   9:30 PM        UD Las Palmas    2:2
# 4      1.Matchday  Sat8/17/24   7:00 PM           CA Osasuna    1:1
# ...           ...         ...       ...                  ...    ...
# 3035  38.Matchday         NaN   8:45 PM      (5.) Villarreal   2:02
# 3036  38.Matchday  Sun5/20/18  12:00 PM        (4.) Valencia   2:01
# 3037  38.Matchday         NaN   4:15 PM  (16.) Athletic Club   0:01
# 3038  38.Matchday         NaN   6:30 PM        (2.) Atlético   2:02
# 3039  38.Matchday         NaN   8:45 PM       (1.) Barcelona   1:00
#
#                       Away     Season  Home Position
# 0                   Getafe  2024-2025              0
# 1                   Girona  2024-2025              0
# 2                   Alavés  2024-2025              0
# 3               Sevilla FC  2024-2025              0
# 4               CD Leganés  2024-2025              0
# ...                    ...        ...            ...
# 3035      Real Madrid (3.)  2017-2018              5
# 3036  Dep. La Coruña (18.)  2017-2018              4
# 3037        Espanyol (13.)  2017-2018             16
# 3038         SD Eibar (9.)  2017-2018              2
# 3039   Real Sociedad (10.)  2017-2018              1
#
# [3040 rows x 8 columns]

# %%
all_seasons_df.head(20)
# Out:
#       Matchday        Date     Time                Home Result  \
# 0   1.Matchday  Thu8/15/24  7:00 PM       Athletic Club    1:1
# 1   1.Matchday         NaN  9:30 PM          Real Betis    1:1
# 2   1.Matchday  Fri8/16/24  7:00 PM       Celta de Vigo    2:1
# 3   1.Matchday         NaN  9:30 PM       UD Las Palmas    2:2
# 4   1.Matchday  Sat8/17/24  7:00 PM          CA Osasuna    1:1
# 5   1.Matchday         NaN  9:30 PM            Valencia    1:2
# 6   1.Matchday  Sun8/18/24  7:00 PM       Real Sociedad    1:2
# 7   1.Matchday         NaN  9:30 PM        RCD Mallorca    1:1
# 8   1.Matchday  Mon8/19/24  7:00 PM     Real Valladolid    1:0
# 9   1.Matchday         NaN  9:30 PM          Villarreal    2:2
# 10  2.Matchday  Fri8/23/24  7:00 PM  (2.) Celta de Vigo    3:1
# 11  2.Matchday         NaN  9:30 PM     (6.) Sevilla FC    1:2
# 12  2.Matchday  Sat8/24/24  5:00 PM    (11.) CA Osasuna    1:0
# 13  2.Matchday         NaN  7:00 PM      (1.) Barcelona    2:1
# 14  2.Matchday         NaN  9:30 PM        (13.) Getafe    0:0
# 15  2.Matchday         NaN      NaN      (20.) Espanyol    0:1
# 16  2.Matchday  Sun8/25/24  5:00 PM    (9.) Real Madrid    3:0
# 17  2.Matchday         NaN  7:00 PM    (16.) CD Leganés    2:1
# 18  2.Matchday         NaN  7:15 PM        (18.) Alavés    0:0
# 19  2.Matchday         NaN  9:30 PM       (5.) Atlético    3:0
#
#                     Away     Season  Home Position
# 0                 Getafe  2024-2025              0
# 1                 Girona  2024-2025              0
# 2                 Alavés  2024-2025              0
# 3             Sevilla FC  2024-2025              0
# 4             CD Leganés  2024-2025              0
# 5              Barcelona  2024-2025              0
# 6         Rayo Vallecano  2024-2025              0
# 7            Real Madrid  2024-2025              0
# 8               Espanyol  2024-2025              0
# 9               Atlético  2024-2025              0
# 10        Valencia (19.)  2024-2025              2
# 11       Villarreal (7.)  2024-2025              6
# 12    RCD Mallorca (14.)  2024-2025             11
# 13   Athletic Club (12.)  2024-2025              1
# 14   Rayo Vallecano (3.)  2024-2025             13
# 15   Real Sociedad (17.)  2024-2025             20
# 16  Real Valladolid (4.)  2024-2025              9
# 17    UD Las Palmas (8.)  2024-2025             16
# 18      Real Betis (10.)  2024-2025             18
# 19          Girona (15.)  2024-2025              5

# %%
all_seasons_df['Home'] = all_seasons_df['Home'].str.replace(r'^\(\d+\.\)\s*', '', regex=True)

# %%
all_seasons_df['Home'].unique()
# Out:
# array(['Athletic Club', 'Real Betis', 'Celta de Vigo', 'UD Las Palmas',
#        'CA Osasuna', 'Valencia', 'Real Sociedad', 'RCD Mallorca',
#        'Real Valladolid', 'Villarreal', 'Sevilla FC', 'Barcelona',
#        'Getafe', 'Espanyol', 'Real Madrid', 'CD Leganés', 'Alavés',
#        'Atlético', 'Rayo Vallecano', 'Girona', 'UD Almería', 'Cádiz CF',
#        'Granada CF', 'Elche CF', 'Levante', 'SD Eibar', 'SD Huesca',
#        'Dep. La Coruña', 'Málaga CF'], dtype=object)

# %%
all_seasons_df['Away'].unique()
# Out:
# array(['Getafe', 'Girona', 'Alavés', 'Sevilla FC', 'CD Leganés',
#        'Barcelona', 'Rayo Vallecano', 'Real Madrid', 'Espanyol',
#        'Atlético', 'Valencia (19.)', 'Villarreal (7.)',
#        'RCD Mallorca (14.)', 'Athletic Club (12.)', 'Rayo Vallecano (3.)',
#        'Real Sociedad (17.)', 'Real Valladolid (4.)',
#        'UD Las Palmas (8.)', 'Real Betis (10.)', 'Girona (15.)',
#        'Celta de Vigo (1.)', 'Sevilla FC (13.)', 'Barcelona (2.)',
#        'Valencia (20.)', 'CD Leganés (6.)', 'Alavés (16.)',
#        'Espanyol (19.)', 'CA Osasuna (7.)', 'Real Madrid (4.)',
#        'Getafe (12.)', 'Real Valladolid (12.)', 'Atlético (4.)',
#        'Rayo Vallecano (11.)', 'Villarreal (2.)', 'RCD Mallorca (18.)',
#        'UD Las Palmas (15.)', 'Celta de Vigo (3.)', 'Girona (8.)',
#        'Real Sociedad (14.)', 'Real Betis (6.)', 'CD Leganés (11.)',
#        'Villarreal (4.)', 'Alavés (6.)', 'Getafe (17.)',
#        'Real Madrid (2.)', 'Barcelona (1.)', 'Athletic Club (15.)',
#        'Sevilla FC (14.)', 'Real Sociedad (16.)', 'UD Las Palmas (19.)',
#        'Girona (7.)', 'Espanyol (8.)', 'CD Leganés (15.)',
#        'Celta de Vigo (5.)', 'Atlético (2.)', 'RCD Mallorca (13.)',
#        'Athletic Club (5.)', 'Real Valladolid (17.)',
#        'Rayo Vallecano (10.)', 'Getafe (18.)', 'Real Betis (11.)',
#        'Atlético (3.)', 'RCD Mallorca (7.)', 'Alavés (8.)',
#        'Valencia (17.)', 'Girona (12.)', 'Espanyol (14.)',
#        'UD Las Palmas (20.)', 'Valencia (18.)', 'CA Osasuna (5.)',
#        'Celta de Vigo (9.)', 'Villarreal (3.)', 'Athletic Club (6.)',
#        'Real Betis (8.)', 'Real Valladolid (19.)', 'Espanyol (13.)',
#        'Real Sociedad (15.)', 'Rayo Vallecano (8.)', 'CD Leganés (17.)',
#        'Getafe (16.)', 'Sevilla FC (12.)', 'Alavés (15.)',
#        'Celta de Vigo (10.)', 'CA Osasuna (8.)', 'CD Leganés (14.)',
#        'UD Las Palmas (18.)', 'Espanyol (16.)', 'Real Sociedad (12.)',
#        'Getafe (15.)', 'Rayo Vallecano (9.)', 'Alavés (14.)',
#        'Real Betis (7.)', 'RCD Mallorca (8.)', 'Espanyol (17.)',
#        'Real Sociedad (9.)', 'UD Las Palmas (17.)', 'Celta de Vigo (11.)',
#        'Real Betis (9.)', 'CA Osasuna (6.)', 'RCD Mallorca (6.)',
#        'Real Valladolid (20.)', 'Rayo Vallecano (13.)',
#        'Real Madrid (1.)', 'Alavés (17.)', 'Sevilla FC (11.)',
#        'Girona (9.)', 'Athletic Club (4.)', 'UD Las Palmas (14.)',
#        'Real Sociedad (8.)', 'Villarreal (5.)', 'Espanyol (18.)',
#        'Rayo Vallecano (12.)', 'Barcelona (3.)', 'CA Osasuna (10.)',
#        'Atlético (1.)', 'Real Sociedad (7.)', 'CA Osasuna (11.)',
#        'Real Betis (12.)', 'Celta de Vigo (13.)', 'Rayo Vallecano (7.)',
#        'UD Las Palmas (16.)', 'Getafe (14.)', 'Alavés (19.)',
#        'Real Sociedad (10.)', 'Rayo Vallecano (6.)', 'CA Osasuna (9.)',
#        'Espanyol (15.)', 'Girona (11.)', 'CD Leganés (16.)',
#        'Celta de Vigo (12.)', 'Sevilla FC (10.)', 'Girona (13.)',
#        'Alavés (18.)', 'Valencia (16.)', 'Real Sociedad (11.)',
#        'Getafe (13.)', 'CD Leganés (18.)', 'CA Osasuna (14.)',
#        'Valencia (15.)', 'Celta de Vigo (7.)', 'RCD Mallorca (9.)',
#        'Getafe (11.)', 'Valencia (13.)', 'CD Leganés (19.)',
#        'CA Osasuna (12.)', 'Sevilla FC (15.)', 'Girona (16.)',
#        'Valencia (14.)', 'Sevilla FC (16.)', 'Valencia (11.)',
#        'Valencia (12.)', 'RCD Mallorca (10.)', 'Valencia', 'RCD Mallorca',
#        'CA Osasuna', 'Real Betis', 'Granada CF', 'Villarreal (15.)',
#        'UD Las Palmas (10.)', 'Celta de Vigo (20.)', 'Real Madrid (3.)',
#        'Athletic Club (18.)', 'Cádiz CF (7.)', 'Rayo Vallecano (4.)',
#        'Real Sociedad (13.)', 'UD Almería (20.)', 'RCD Mallorca (15.)',
#        'Girona (4.)', 'Barcelona (6.)', 'Atlético (5.)',
#        'Villarreal (13.)', 'Celta de Vigo (18.)', 'Granada CF (15.)',
#        'Valencia (7.)', 'Barcelona (4.)', 'Sevilla FC (20.)',
#        'Alavés (10.)', 'Cádiz CF (6.)', 'RCD Mallorca (17.)',
#        'UD Almería (19.)', 'Girona (3.)', 'Sevilla FC (17.)',
#        'Celta de Vigo (16.)', 'Valencia (6.)', 'Getafe (8.)',
#        'Cádiz CF (9.)', 'Granada CF (18.)', 'Girona (2.)',
#        'RCD Mallorca (16.)', 'Granada CF (19.)', 'Valencia (8.)',
#        'Celta de Vigo (17.)', 'Valencia (10.)', 'Real Sociedad (5.)',
#        'Cádiz CF (13.)', 'UD Las Palmas (12.)', 'Villarreal (14.)',
#        'Cádiz CF (15.)', 'Girona (1.)', 'Cádiz CF (16.)',
#        'Real Sociedad (6.)', 'Alavés (13.)', 'Villarreal (12.)',
#        'Getafe (9.)', 'Cádiz CF (17.)', 'Alavés (12.)',
#        'UD Las Palmas (9.)', 'Valencia (9.)', 'Cádiz CF (18.)',
#        'Getafe (10.)', 'Rayo Vallecano (14.)', 'Rayo Vallecano (16.)',
#        'UD Las Palmas (11.)', 'Rayo Vallecano (15.)', 'Villarreal (10.)',
#        'Villarreal (9.)', 'CA Osasuna (13.)', 'Celta de Vigo (15.)',
#        'Alavés (11.)', 'Villarreal (8.)', 'Villarreal', 'Real Sociedad',
#        'Elche CF', 'Real Betis (2.)', 'Barcelona (10.)',
#        'UD Almería (15.)', 'Getafe (19.)', 'CA Osasuna (4.)',
#        'Villarreal (1.)', 'Real Valladolid (18.)', 'Athletic Club (7.)',
#        'Atlético (8.)', 'Cádiz CF (20.)', 'Atlético (6.)',
#        'Elche CF (17.)', 'UD Almería (10.)', 'Real Valladolid (16.)',
#        'Celta de Vigo (8.)', 'RCD Mallorca (11.)', 'UD Almería (14.)',
#        'Elche CF (19.)', 'UD Almería (16.)', 'Villarreal (6.)',
#        'Atlético (7.)', 'Real Betis (3.)', 'Elche CF (20.)',
#        'Athletic Club (3.)', 'Real Betis (4.)', 'RCD Mallorca (12.)',
#        'Cádiz CF (19.)', 'Sevilla FC (18.)', 'Real Valladolid (13.)',
#        'Real Sociedad (3.)', 'UD Almería (13.)', 'Real Valladolid (11.)',
#        'Girona (18.)', 'Real Betis (5.)', 'Girona (14.)',
#        'Real Valladolid (10.)', 'Real Valladolid (15.)',
#        'Athletic Club (8.)', 'UD Almería (11.)', 'Rayo Vallecano (5.)',
#        'Celta de Vigo (14.)', 'Espanyol (12.)', 'Athletic Club (9.)',
#        'Real Valladolid (14.)', 'Real Sociedad (4.)', 'UD Almería (18.)',
#        'Girona (10.)', 'Cádiz CF (14.)', 'Sevilla FC (9.)',
#        'UD Almería (17.)', 'Levante', 'Athletic Club', 'Valencia (5.)',
#        'Rayo Vallecano (20.)', 'Elche CF (15.)', 'Sevilla FC (2.)',
#        'Espanyol (10.)', 'Levante (11.)', 'Sevilla FC (1.)',
#        'Granada CF (13.)', 'Valencia (3.)', 'Real Betis (14.)',
#        'Alavés (20.)', 'Levante (14.)', 'Sevilla FC (6.)',
#        'Granada CF (17.)', 'Elche CF (13.)', 'Barcelona (5.)',
#        'Athletic Club (10.)', 'Levante (17.)', 'Real Sociedad (2.)',
#        'Sevilla FC (3.)', 'Getafe (20.)', 'Elche CF (14.)',
#        'Sevilla FC (4.)', 'Levante (18.)', 'Barcelona (8.)',
#        'Espanyol (11.)', 'Granada CF (14.)', 'Barcelona (9.)',
#        'Levante (19.)', 'Barcelona (7.)', 'Levante (20.)',
#        'Elche CF (18.)', 'Elche CF (16.)', 'Espanyol (9.)',
#        'Villarreal (11.)', 'Granada CF (12.)', 'Granada CF (16.)',
#        'Celta de Vigo', 'SD Huesca', 'SD Eibar (12.)', 'Valencia (2.)',
#        'SD Huesca (17.)', 'Real Madrid (5.)', 'Levante (15.)',
#        'Athletic Club (19.)', 'Granada CF (2.)', 'Levante (10.)',
#        'SD Eibar (19.)', 'Getafe (7.)', 'SD Huesca (14.)',
#        'Granada CF (4.)', 'Cádiz CF (10.)', 'Athletic Club (14.)',
#        'SD Eibar (15.)', 'Granada CF (3.)', 'SD Huesca (19.)',
#        'Sevilla FC (8.)', 'Elche CF (11.)', 'SD Eibar (16.)',
#        'Athletic Club (13.)', 'SD Huesca (20.)', 'Elche CF (10.)',
#        'Cádiz CF (8.)', 'Sevilla FC (7.)', 'Athletic Club (11.)',
#        'Granada CF (6.)', 'Elche CF (9.)', 'CA Osasuna (18.)',
#        'Athletic Club (16.)', 'SD Eibar (11.)', 'Granada CF (8.)',
#        'Elche CF (12.)', 'CA Osasuna (20.)', 'SD Eibar (14.)',
#        'SD Eibar (17.)', 'Levante (9.)', 'CA Osasuna (19.)',
#        'Cádiz CF (11.)', 'SD Eibar (13.)', 'Granada CF (7.)',
#        'Levante (12.)', 'CA Osasuna (17.)', 'CA Osasuna (15.)',
#        'Granada CF (10.)', 'SD Huesca (16.)', 'SD Eibar (20.)',
#        'Levante (13.)', 'SD Huesca (18.)', 'Granada CF (9.)',
#        'Cádiz CF (12.)', 'SD Eibar', 'Real Valladolid',
#        'Real Valladolid (3.)', 'Espanyol (20.)', 'Alavés (7.)',
#        'Levante (4.)', 'Villarreal (16.)', 'Real Betis (16.)',
#        'CD Leganés (20.)', 'Granada CF (5.)', 'Athletic Club (1.)',
#        'RCD Mallorca (19.)', 'Real Betis (15.)', 'Real Betis (17.)',
#        'Real Valladolid (8.)', 'Sevilla FC (5.)', 'Granada CF (1.)',
#        'Getafe (4.)', 'Real Betis (13.)', 'Getafe (5.)', 'Getafe (3.)',
#        'Getafe (6.)', 'Real Betis (20.)', 'Rayo Vallecano (18.)',
#        'SD Huesca (7.)', 'Atlético (9.)', 'Espanyol (3.)',
#        'SD Huesca (5.)', 'Villarreal (18.)', 'Levante (7.)',
#        'Alavés (5.)', 'Alavés (4.)', 'Espanyol (6.)', 'SD Eibar (8.)',
#        'Celta de Vigo (4.)', 'Levante (16.)', 'Athletic Club (17.)',
#        'Real Valladolid (7.)', 'Rayo Vallecano (19.)', 'Real Madrid (7.)',
#        'Real Valladolid (6.)', 'Alavés (2.)', 'Espanyol (2.)',
#        'Real Madrid (6.)', 'SD Eibar (10.)', 'Espanyol (5.)',
#        'Levante (8.)', 'Girona (6.)', 'Villarreal (17.)',
#        'Villarreal (19.)', 'CD Leganés (13.)', 'CD Leganés (12.)',
#        'Girona (17.)', 'Alavés (9.)', 'Valencia (4.)', 'UD Las Palmas',
#        'Málaga CF (17.)', 'Dep. La Coruña (20.)', 'Real Sociedad (1.)',
#        'CD Leganés (5.)', 'Dep. La Coruña (17.)', 'Málaga CF (19.)',
#        'Real Madrid (8.)', 'Dep. La Coruña (18.)', 'Dep. La Coruña (15.)',
#        'CD Leganés (7.)', 'Málaga CF (20.)', 'Dep. La Coruña (16.)',
#        'CD Leganés (8.)', 'Málaga CF (18.)', 'SD Eibar (7.)',
#        'CD Leganés (9.)', 'Dep. La Coruña (19.)', 'SD Eibar (9.)'],
#       dtype=object)

# %% [markdown]
# ## Extracting Away Positions

# %%
all_seasons_df['Away Position'] = (
    all_seasons_df['Away']
    .str.extract(r'\((\d+)\.\)$')   # match (number.) at the END of the string
    .fillna(0)
    .astype(int)
)

# %%
all_seasons_df.head(20)
# Out:
#       Matchday        Date     Time             Home Result  \
# 0   1.Matchday  Thu8/15/24  7:00 PM    Athletic Club    1:1
# 1   1.Matchday         NaN  9:30 PM       Real Betis    1:1
# 2   1.Matchday  Fri8/16/24  7:00 PM    Celta de Vigo    2:1
# 3   1.Matchday         NaN  9:30 PM    UD Las Palmas    2:2
# 4   1.Matchday  Sat8/17/24  7:00 PM       CA Osasuna    1:1
# 5   1.Matchday         NaN  9:30 PM         Valencia    1:2
# 6   1.Matchday  Sun8/18/24  7:00 PM    Real Sociedad    1:2
# 7   1.Matchday         NaN  9:30 PM     RCD Mallorca    1:1
# 8   1.Matchday  Mon8/19/24  7:00 PM  Real Valladolid    1:0
# 9   1.Matchday         NaN  9:30 PM       Villarreal    2:2
# 10  2.Matchday  Fri8/23/24  7:00 PM    Celta de Vigo    3:1
# 11  2.Matchday         NaN  9:30 PM       Sevilla FC    1:2
# 12  2.Matchday  Sat8/24/24  5:00 PM       CA Osasuna    1:0
# 13  2.Matchday         NaN  7:00 PM        Barcelona    2:1
# 14  2.Matchday         NaN  9:30 PM           Getafe    0:0
# 15  2.Matchday         NaN      NaN         Espanyol    0:1
# 16  2.Matchday  Sun8/25/24  5:00 PM      Real Madrid    3:0
# 17  2.Matchday         NaN  7:00 PM       CD Leganés    2:1
# 18  2.Matchday         NaN  7:15 PM           Alavés    0:0
# 19  2.Matchday         NaN  9:30 PM         Atlético    3:0
#
#                     Away     Season  Home Position  Away Position
# 0                 Getafe  2024-2025              0              0
# 1                 Girona  2024-2025              0              0
# 2                 Alavés  2024-2025              0              0
# 3             Sevilla FC  2024-2025              0              0
# 4             CD Leganés  2024-2025              0              0
# 5              Barcelona  2024-2025              0              0
# 6         Rayo Vallecano  2024-2025              0              0
# 7            Real Madrid  2024-2025              0              0
# 8               Espanyol  2024-2025              0              0
# 9               Atlético  2024-2025              0              0
# 10        Valencia (19.)  2024-2025              2             19
# 11       Villarreal (7.)  2024-2025              6              7
# 12    RCD Mallorca (14.)  2024-2025             11             14
# 13   Athletic Club (12.)  2024-2025              1             12
# 14   Rayo Vallecano (3.)  2024-2025             13              3
# 15   Real Sociedad (17.)  2024-2025             20             17
# 16  Real Valladolid (4.)  2024-2025              9              4
# 17    UD Las Palmas (8.)  2024-2025             16              8
# 18      Real Betis (10.)  2024-2025             18             10
# 19          Girona (15.)  2024-2025              5             15

# %%
all_seasons_df['Away'] = all_seasons_df['Away'].str.replace(r'\s*\(\d+\.\)$', '', regex=True)

# %%
all_seasons_df['Away'].unique()
# Out:
# array(['Getafe', 'Girona', 'Alavés', 'Sevilla FC', 'CD Leganés',
#        'Barcelona', 'Rayo Vallecano', 'Real Madrid', 'Espanyol',
#        'Atlético', 'Valencia', 'Villarreal', 'RCD Mallorca',
#        'Athletic Club', 'Real Sociedad', 'Real Valladolid',
#        'UD Las Palmas', 'Real Betis', 'Celta de Vigo', 'CA Osasuna',
#        'Granada CF', 'Cádiz CF', 'UD Almería', 'Elche CF', 'Levante',
#        'SD Huesca', 'SD Eibar', 'Málaga CF', 'Dep. La Coruña'],
#       dtype=object)

# %%
set(all_seasons_df['Home'].unique()) == set(all_seasons_df['Away'].unique())
# Out:
# True

# %%
all_seasons_df
# Out:
#          Matchday        Date      Time           Home Result            Away  \
# 0      1.Matchday  Thu8/15/24   7:00 PM  Athletic Club    1:1          Getafe
# 1      1.Matchday         NaN   9:30 PM     Real Betis    1:1          Girona
# 2      1.Matchday  Fri8/16/24   7:00 PM  Celta de Vigo    2:1          Alavés
# 3      1.Matchday         NaN   9:30 PM  UD Las Palmas    2:2      Sevilla FC
# 4      1.Matchday  Sat8/17/24   7:00 PM     CA Osasuna    1:1      CD Leganés
# ...           ...         ...       ...            ...    ...             ...
# 3035  38.Matchday         NaN   8:45 PM     Villarreal   2:02     Real Madrid
# 3036  38.Matchday  Sun5/20/18  12:00 PM       Valencia   2:01  Dep. La Coruña
# 3037  38.Matchday         NaN   4:15 PM  Athletic Club   0:01        Espanyol
# 3038  38.Matchday         NaN   6:30 PM       Atlético   2:02        SD Eibar
# 3039  38.Matchday         NaN   8:45 PM      Barcelona   1:00   Real Sociedad
#
#          Season  Home Position  Away Position
# 0     2024-2025              0              0
# 1     2024-2025              0              0
# 2     2024-2025              0              0
# 3     2024-2025              0              0
# 4     2024-2025              0              0
# ...         ...            ...            ...
# 3035  2017-2018              5              3
# 3036  2017-2018              4             18
# 3037  2017-2018             16             13
# 3038  2017-2018              2              9
# 3039  2017-2018              1             10
#
# [3040 rows x 9 columns]

# %% [markdown]
# ## Filling the relevant date for the missing values

# %%
def fill_and_format_dates(df, date_col='Date'):
    # Fill missing values with the previous non-null value
    df[date_col] = df[date_col].ffill()

    # Function to parse the date strings like 'Thu8/15/24' to datetime objects
    def parse_date(date_str):
        # Extract the part after the weekday prefix (assuming it's always 3 letters)
        date_part = date_str[3:]
        # Parse the date assuming it's in M/D/YY format
        return datetime.strptime(date_part, '%m/%d/%y').date()

    # Apply the parsing function
    df[date_col] = df[date_col].apply(parse_date)

    return df

# %%
df_filled = fill_and_format_dates(all_seasons_df)

# %%
df_filled
# Out:
#          Matchday        Date      Time           Home Result            Away  \
# 0      1.Matchday  2024-08-15   7:00 PM  Athletic Club    1:1          Getafe
# 1      1.Matchday  2024-08-15   9:30 PM     Real Betis    1:1          Girona
# 2      1.Matchday  2024-08-16   7:00 PM  Celta de Vigo    2:1          Alavés
# 3      1.Matchday  2024-08-16   9:30 PM  UD Las Palmas    2:2      Sevilla FC
# 4      1.Matchday  2024-08-17   7:00 PM     CA Osasuna    1:1      CD Leganés
# ...           ...         ...       ...            ...    ...             ...
# 3035  38.Matchday  2018-05-19   8:45 PM     Villarreal   2:02     Real Madrid
# 3036  38.Matchday  2018-05-20  12:00 PM       Valencia   2:01  Dep. La Coruña
# 3037  38.Matchday  2018-05-20   4:15 PM  Athletic Club   0:01        Espanyol
# 3038  38.Matchday  2018-05-20   6:30 PM       Atlético   2:02        SD Eibar
# 3039  38.Matchday  2018-05-20   8:45 PM      Barcelona   1:00   Real Sociedad
#
#          Season  Home Position  Away Position
# 0     2024-2025              0              0
# 1     2024-2025              0              0
# 2     2024-2025              0              0
# 3     2024-2025              0              0
# 4     2024-2025              0              0
# ...         ...            ...            ...
# 3035  2017-2018              5              3
# 3036  2017-2018              4             18
# 3037  2017-2018             16             13
# 3038  2017-2018              2              9
# 3039  2017-2018              1             10
#
# [3040 rows x 9 columns]

# %% [markdown]
# ## Filling the relevant time for the missing values

# %%
def fill_and_format_times(df, time_col='Time'):
    # Step 1: Forward fill missing time values
    df[time_col] = df[time_col].ffill()

    # Step 2: Define parser for 12-hour time format
    def parse_time(t):
        try:
            return datetime.strptime(t.strip(), "%I:%M %p").time()
        except Exception as e:
            print(f"Error parsing time: {t} -> {e}")
            return None

    # Step 3: Apply the parser
    df[time_col] = df[time_col].apply(parse_time)

    return df

# %%
df_filled['Time'].isnull().sum()
# Out:
# np.int64(269)

# %%
df_filled = fill_and_format_times(df_filled, time_col='Time')

# %%
df_filled
# Out:
#          Matchday        Date      Time           Home Result            Away  \
# 0      1.Matchday  2024-08-15  19:00:00  Athletic Club    1:1          Getafe
# 1      1.Matchday  2024-08-15  21:30:00     Real Betis    1:1          Girona
# 2      1.Matchday  2024-08-16  19:00:00  Celta de Vigo    2:1          Alavés
# 3      1.Matchday  2024-08-16  21:30:00  UD Las Palmas    2:2      Sevilla FC
# 4      1.Matchday  2024-08-17  19:00:00     CA Osasuna    1:1      CD Leganés
# ...           ...         ...       ...            ...    ...             ...
# 3035  38.Matchday  2018-05-19  20:45:00     Villarreal   2:02     Real Madrid
# 3036  38.Matchday  2018-05-20  12:00:00       Valencia   2:01  Dep. La Coruña
# 3037  38.Matchday  2018-05-20  16:15:00  Athletic Club   0:01        Espanyol
# 3038  38.Matchday  2018-05-20  18:30:00       Atlético   2:02        SD Eibar
# 3039  38.Matchday  2018-05-20  20:45:00      Barcelona   1:00   Real Sociedad
#
#          Season  Home Position  Away Position
# 0     2024-2025              0              0
# 1     2024-2025              0              0
# 2     2024-2025              0              0
# 3     2024-2025              0              0
# 4     2024-2025              0              0
# ...         ...            ...            ...
# 3035  2017-2018              5              3
# 3036  2017-2018              4             18
# 3037  2017-2018             16             13
# 3038  2017-2018              2              9
# 3039  2017-2018              1             10
#
# [3040 rows x 9 columns]

# %%
df_filled.isnull().sum()
# Out:
# Matchday         0
# Date             0
# Time             0
# Home             0
# Result           0
# Away             0
# Season           0
# Home Position    0
# Away Position    0
# dtype: int64

# %%
df_filled['Home'].unique()
# Out:
# array(['Athletic Club', 'Real Betis', 'Celta de Vigo', 'UD Las Palmas',
#        'CA Osasuna', 'Valencia', 'Real Sociedad', 'RCD Mallorca',
#        'Real Valladolid', 'Villarreal', 'Sevilla FC', 'Barcelona',
#        'Getafe', 'Espanyol', 'Real Madrid', 'CD Leganés', 'Alavés',
#        'Atlético', 'Rayo Vallecano', 'Girona', 'UD Almería', 'Cádiz CF',
#        'Granada CF', 'Elche CF', 'Levante', 'SD Eibar', 'SD Huesca',
#        'Dep. La Coruña', 'Málaga CF'], dtype=object)

# %%
df_filled['Away'].unique()
# Out:
# array(['Getafe', 'Girona', 'Alavés', 'Sevilla FC', 'CD Leganés',
#        'Barcelona', 'Rayo Vallecano', 'Real Madrid', 'Espanyol',
#        'Atlético', 'Valencia', 'Villarreal', 'RCD Mallorca',
#        'Athletic Club', 'Real Sociedad', 'Real Valladolid',
#        'UD Las Palmas', 'Real Betis', 'Celta de Vigo', 'CA Osasuna',
#        'Granada CF', 'Cádiz CF', 'UD Almería', 'Elche CF', 'Levante',
#        'SD Huesca', 'SD Eibar', 'Málaga CF', 'Dep. La Coruña'],
#       dtype=object)

# %% [markdown]
# ## Load data scraped from FBRef

# %%
data = pd.read_csv('LaLigaFixturesFBREF.csv')

# %%
data.head(2)
# Out:
#       Season   Wk  Day        Date   Time           Home   xG Score  xG.1  \
# 0  2024-2025  1.0  Thu  2024-08-15  19:00  Athletic Club  0.3   1–1   0.8
# 1  2024-2025  1.0  Thu  2024-08-15  21:30          Betis  1.4   1–1   1.6
#
#      Away  Attendance                      Venue                   Referee
# 0  Getafe     47845.0                  San Mamés           Alejandro Muñíz
# 1  Girona     54084.0  Estadio Benito Villamarín  Miguel Ángel Ortiz Arias

# %%
data['Home'].unique()
# Out:
# array(['Athletic Club', 'Betis', 'Celta Vigo', 'Las Palmas', 'Osasuna',
#        'Valencia', 'Real Sociedad', 'Mallorca', 'Valladolid',
#        'Villarreal', 'Sevilla', 'Barcelona', 'Getafe', 'Espanyol',
#        'Real Madrid', 'Leganés', 'Alavés', 'Atlético Madrid',
#        'Rayo Vallecano', 'Girona', 'Almería', 'Cádiz', 'Granada', 'Elche',
#        'Levante', 'Eibar', 'Huesca', 'La Coruña', 'Málaga'], dtype=object)

# %%
data['Away'].unique()
# Out:
# array(['Getafe', 'Girona', 'Alavés', 'Sevilla', 'Leganés', 'Barcelona',
#        'Rayo Vallecano', 'Real Madrid', 'Espanyol', 'Atlético Madrid',
#        'Valencia', 'Villarreal', 'Mallorca', 'Athletic Club',
#        'Real Sociedad', 'Valladolid', 'Las Palmas', 'Betis', 'Celta Vigo',
#        'Osasuna', 'Granada', 'Cádiz', 'Almería', 'Elche', 'Levante',
#        'Huesca', 'Eibar', 'La Coruña', 'Málaga'], dtype=object)

# %% [markdown]
# ## Mapping dictionary to unify team names from both df_filled and data

# %%
team_name_map = {
    # Athletic Club
    "Athletic Club": "Athletic Club",
    
    # Real Betis variations
    "Real Betis": "Real Betis",
    "Betis": "Real Betis",
    
    # Celta de Vigo variations
    "Celta de Vigo": "Celta Vigo",
    "Celta Vigo": "Celta Vigo",
    
    # UD Las Palmas variations
    "UD Las Palmas": "Las Palmas",
    "Las Palmas": "Las Palmas",
    
    # CA Osasuna variations
    "CA Osasuna": "Osasuna",
    "Osasuna": "Osasuna",
    
    # Valencia
    "Valencia": "Valencia",
    
    # Real Sociedad
    "Real Sociedad": "Real Sociedad",
    
    # RCD Mallorca variations
    "RCD Mallorca": "Mallorca",
    "Mallorca": "Mallorca",
    
    # Real Valladolid
    "Real Valladolid": "Valladolid",
    "Valladolid": "Valladolid",
    
    # Villarreal
    "Villarreal": "Villarreal",
    
    # Sevilla FC variations
    "Sevilla FC": "Sevilla",
    "Sevilla": "Sevilla",
    
    # Barcelona
    "Barcelona": "Barcelona",
    
    # Getafe
    "Getafe": "Getafe",
    
    # Espanyol
    "Espanyol": "Espanyol",
    
    # Real Madrid
    "Real Madrid": "Real Madrid",
    
    # CD Leganés variations
    "CD Leganés": "Leganes",
    "Leganés": "Leganes",
    "Leganés": "Leganes",
    "Leganes": "Leganes",
    "Leganés": "Leganes",
    "Leganés": "Leganes",
    "Leganés": "Leganes",
    
    # Alavés variations
    "Alavés": "Alaves",
    "Alaves": "Alaves",
    
    # Atlético / Atlético Madrid variations
    "Atlético": "Atletico Madrid",
    "Atlético Madrid": "Atletico Madrid",
    "Atletico Madrid": "Atletico Madrid",
    
    # Rayo Vallecano
    "Rayo Vallecano": "Rayo Vallecano",
    
    # Girona
    "Girona": "Girona",
    
    # UD Almería variations
    "UD Almería": "Almeria",
    "Almería": "Almeria",
    "Almeria": "Almeria",
    
    # Cádiz CF variations
    "Cádiz CF": "Cadiz",
    "Cádiz": "Cadiz",
    "Cadiz": "Cadiz",
    
    # Granada CF variations
    "Granada CF": "Granada",
    "Granada": "Granada",
    
    # Elche CF variations
    "Elche CF": "Elche",
    "Elche": "Elche",
    
    # Levante
    "Levante": "Levante",
    
    # SD Eibar variations
    "SD Eibar": "Eibar",
    "Eibar": "Eibar",
    
    # SD Huesca variations
    "SD Huesca": "Huesca",
    "Huesca": "Huesca",
    
    # Deportivo La Coruña variations
    "Dep. La Coruña": "Deportivo La Coruna",
    "La Coruña": "Deportivo La Coruna",
    "Deportivo La Coruna": "Deportivo La Coruna",
    
    # Málaga CF variations
    "Málaga CF": "Malaga",
    "Málaga": "Malaga",
    "Malaga": "Malaga",
}

# %%
df_filled['Home'] = df_filled['Home'].map(team_name_map).fillna(df_filled['Home'])
df_filled['Away'] = df_filled['Away'].map(team_name_map).fillna(df_filled['Away'])

# %%
data['Home'] = data['Home'].map(team_name_map).fillna(data['Home'])
data['Away'] = data['Away'].map(team_name_map).fillna(data['Away'])

# %%
df_filled['Home'].unique()
# Out:
# array(['Athletic Club', 'Real Betis', 'Celta Vigo', 'Las Palmas',
#        'Osasuna', 'Valencia', 'Real Sociedad', 'Mallorca', 'Valladolid',
#        'Villarreal', 'Sevilla', 'Barcelona', 'Getafe', 'Espanyol',
#        'Real Madrid', 'Leganes', 'Alaves', 'Atletico Madrid',
#        'Rayo Vallecano', 'Girona', 'Almeria', 'Cadiz', 'Granada', 'Elche',
#        'Levante', 'Eibar', 'Huesca', 'Deportivo La Coruna', 'Malaga'],
#       dtype=object)

# %%
df_filled['Away'].unique()
# Out:
# array(['Getafe', 'Girona', 'Alaves', 'Sevilla', 'Leganes', 'Barcelona',
#        'Rayo Vallecano', 'Real Madrid', 'Espanyol', 'Atletico Madrid',
#        'Valencia', 'Villarreal', 'Mallorca', 'Athletic Club',
#        'Real Sociedad', 'Valladolid', 'Las Palmas', 'Real Betis',
#        'Celta Vigo', 'Osasuna', 'Granada', 'Cadiz', 'Almeria', 'Elche',
#        'Levante', 'Huesca', 'Eibar', 'Malaga', 'Deportivo La Coruna'],
#       dtype=object)

# %%
data['Home'].unique()
# Out:
# array(['Athletic Club', 'Real Betis', 'Celta Vigo', 'Las Palmas',
#        'Osasuna', 'Valencia', 'Real Sociedad', 'Mallorca', 'Valladolid',
#        'Villarreal', 'Sevilla', 'Barcelona', 'Getafe', 'Espanyol',
#        'Real Madrid', 'Leganes', 'Alaves', 'Atletico Madrid',
#        'Rayo Vallecano', 'Girona', 'Almeria', 'Cadiz', 'Granada', 'Elche',
#        'Levante', 'Eibar', 'Huesca', 'Deportivo La Coruna', 'Malaga'],
#       dtype=object)

# %%
data['Away'].unique()
# Out:
# array(['Getafe', 'Girona', 'Alaves', 'Sevilla', 'Leganes', 'Barcelona',
#        'Rayo Vallecano', 'Real Madrid', 'Espanyol', 'Atletico Madrid',
#        'Valencia', 'Villarreal', 'Mallorca', 'Athletic Club',
#        'Real Sociedad', 'Valladolid', 'Las Palmas', 'Real Betis',
#        'Celta Vigo', 'Osasuna', 'Granada', 'Cadiz', 'Almeria', 'Elche',
#        'Levante', 'Huesca', 'Eibar', 'Deportivo La Coruna', 'Malaga'],
#       dtype=object)

# %%
set(data['Home'].unique()) == set(data['Away'].unique())
# Out:
# True

# %%
set(df_filled['Home'].unique()) == set(df_filled['Away'].unique())
# Out:
# True

# %%
set(df_filled['Home'].unique()) == set(data['Home'].unique())
# Out:
# True

# %%
set(df_filled['Away'].unique()) == set(data['Away'].unique())
# Out:
# True

# %%
df_filled
# Out:
#          Matchday        Date      Time             Home Result  \
# 0      1.Matchday  2024-08-15  19:00:00    Athletic Club    1:1
# 1      1.Matchday  2024-08-15  21:30:00       Real Betis    1:1
# 2      1.Matchday  2024-08-16  19:00:00       Celta Vigo    2:1
# 3      1.Matchday  2024-08-16  21:30:00       Las Palmas    2:2
# 4      1.Matchday  2024-08-17  19:00:00          Osasuna    1:1
# ...           ...         ...       ...              ...    ...
# 3035  38.Matchday  2018-05-19  20:45:00       Villarreal   2:02
# 3036  38.Matchday  2018-05-20  12:00:00         Valencia   2:01
# 3037  38.Matchday  2018-05-20  16:15:00    Athletic Club   0:01
# 3038  38.Matchday  2018-05-20  18:30:00  Atletico Madrid   2:02
# 3039  38.Matchday  2018-05-20  20:45:00        Barcelona   1:00
#
#                      Away     Season  Home Position  Away Position
# 0                  Getafe  2024-2025              0              0
# 1                  Girona  2024-2025              0              0
# 2                  Alaves  2024-2025              0              0
# 3                 Sevilla  2024-2025              0              0
# 4                 Leganes  2024-2025              0              0
# ...                   ...        ...            ...            ...
# 3035          Real Madrid  2017-2018              5              3
# 3036  Deportivo La Coruna  2017-2018              4             18
# 3037             Espanyol  2017-2018             16             13
# 3038                Eibar  2017-2018              2              9
# 3039        Real Sociedad  2017-2018              1             10
#
# [3040 rows x 9 columns]

# %% [markdown]
# ## Converting date in into datetime format

# %%
df_filled['Date'] = pd.to_datetime(df_filled['Date'])

# %%
data['Date'] = pd.to_datetime(data['Date'])

# %%
df_filled.dtypes
# Out:
# Matchday                 object
# Date             datetime64[ns]
# Time                     object
# Home                     object
# Result                   object
# Away                     object
# Season                   object
# Home Position             int64
# Away Position             int64
# dtype: object

# %%
data.dtypes
# Out:
# Season                object
# Wk                   float64
# Day                   object
# Date          datetime64[ns]
# Time                  object
# Home                  object
# xG                   float64
# Score                 object
# xG.1                 float64
# Away                  object
# Attendance           float64
# Venue                 object
# Referee               object
# dtype: object

# %% [markdown]
# ## Sorting both dataframes inorder to join

# %%
df_filled = df_filled.sort_values(by=['Date', 'Home', 'Away'], ascending=[True, True, True]).reset_index(drop=True)

# %%
data = data.sort_values(by=['Date', 'Home', 'Away'], ascending=[True, True, True]).reset_index(drop=True)

# %%
df_filled['Home'].equals(data['Home'])
# Out:
# True

# %%
df_filled['Away'].equals(data['Away'])
# Out:
# True

# %%
df_filled
# Out:
#          Matchday       Date      Time            Home Result  \
# 0      1.Matchday 2017-08-18  20:15:00         Leganes   1:00
# 1      1.Matchday 2017-08-18  22:15:00        Valencia   1:00
# 2      1.Matchday 2017-08-19  18:15:00      Celta Vigo   2:03
# 3      1.Matchday 2017-08-19  20:15:00          Girona   2:02
# 4      1.Matchday 2017-08-19  22:15:00         Sevilla   1:01
# ...           ...        ...       ...             ...    ...
# 3035  38.Matchday 2025-05-24  21:00:00  Rayo Vallecano    0:0
# 3036  38.Matchday 2025-05-24  16:15:00     Real Madrid    2:0
# 3037  38.Matchday 2025-05-25  21:00:00   Athletic Club    0:3
# 3038  38.Matchday 2025-05-25  14:00:00          Girona    0:4
# 3039  38.Matchday 2025-05-25  16:15:00      Villarreal    4:2
#
#                  Away     Season  Home Position  Away Position
# 0              Alaves  2017-2018              0              0
# 1          Las Palmas  2017-2018              0              0
# 2       Real Sociedad  2017-2018              0              0
# 3     Atletico Madrid  2017-2018              0              0
# 4            Espanyol  2017-2018              0              0
# ...               ...        ...            ...            ...
# 3035         Mallorca  2024-2025              8             10
# 3036    Real Sociedad  2024-2025              2             11
# 3037        Barcelona  2024-2025              4              1
# 3038  Atletico Madrid  2024-2025             15              3
# 3039          Sevilla  2024-2025              5             16
#
# [3040 rows x 9 columns]

# %%
print(df_filled.shape)
print(data.shape)
# Out:
# (3040, 9)
# (3040, 13)

# %% [markdown]
# ## Creating one data to proceed to preprocessing with the columns Home Positions and Away Position

# %%
data['Home Position'] = df_filled['Home Position'].values
data['Away Position'] = df_filled['Away Position'].values

# %%
data.head(3)
# Out:
#       Season   Wk  Day       Date   Time        Home   xG Score  xG.1  \
# 0  2017-2018  1.0  Fri 2017-08-18  20:15     Leganes  1.3   1–0   1.1
# 1  2017-2018  1.0  Fri 2017-08-18  22:15    Valencia  1.4   1–0   0.2
# 2  2017-2018  1.0  Sat 2017-08-19  18:15  Celta Vigo  1.8   2–3   2.1
#
#             Away  Attendance                          Venue  \
# 0         Alaves      9231.0  Estadio Municipal de Butarque
# 1     Las Palmas     35971.0            Estadio de Mestalla
# 2  Real Sociedad     16961.0            Estadio de Balaídos
#
#                Referee  Home Position  Away Position
# 0         José Munuera              0              0
# 1            Jesús Gil              0              0
# 2  Antonio Matéu Lahoz              0              0

# %%
data.columns.values
# Out:
# array(['Season', 'Wk', 'Day', 'Date', 'Time', 'Home', 'xG', 'Score',
#        'xG.1', 'Away', 'Attendance', 'Venue', 'Referee', 'Home Position',
#        'Away Position'], dtype=object)

# %%
data = data[['Season', 'Wk', 'Day', 'Date', 'Time','Home Position', 'Home', 'xG', 'Score',
       'xG.1', 'Away','Away Position', 'Attendance', 'Venue', 'Referee']]

# %%
data
# Out:
#          Season    Wk  Day       Date   Time  Home Position            Home  \
# 0     2017-2018   1.0  Fri 2017-08-18  20:15              0         Leganes
# 1     2017-2018   1.0  Fri 2017-08-18  22:15              0        Valencia
# 2     2017-2018   1.0  Sat 2017-08-19  18:15              0      Celta Vigo
# 3     2017-2018   1.0  Sat 2017-08-19  20:15              0          Girona
# 4     2017-2018   1.0  Sat 2017-08-19  22:15              0         Sevilla
# ...         ...   ...  ...        ...    ...            ...             ...
# 3035  2024-2025  38.0  Sat 2025-05-24  21:00              8  Rayo Vallecano
# 3036  2024-2025  38.0  Sat 2025-05-24  16:15              2     Real Madrid
# 3037  2024-2025  38.0  Sun 2025-05-25  21:00              4   Athletic Club
# 3038  2024-2025  38.0  Sun 2025-05-25  14:00             15          Girona
# 3039  2024-2025  38.0  Sun 2025-05-25  16:15              5      Villarreal
#
#        xG Score  xG.1             Away  Away Position  Attendance  \
# 0     1.3   1–0   1.1           Alaves              0      9231.0
# 1     1.4   1–0   0.2       Las Palmas              0     35971.0
# 2     1.8   2–3   2.1    Real Sociedad              0     16961.0
# 3     2.2   2–2   0.7  Atletico Madrid              0     11511.0
# 4     2.4   1–1   1.3         Espanyol              0     30487.0
# ...   ...   ...   ...              ...            ...         ...
# 3035  2.2   0–0   0.6         Mallorca             10     13854.0
# 3036  2.6   2–0   0.8    Real Sociedad             11     73186.0
# 3037  1.2   0–3   3.5        Barcelona              1     50231.0
# 3038  0.0   0–4   2.7  Atletico Madrid              3     11546.0
# 3039  1.1   4–2   1.5          Sevilla             16     17758.0
#
#                               Venue              Referee
# 0     Estadio Municipal de Butarque         José Munuera
# 1               Estadio de Mestalla            Jesús Gil
# 2               Estadio de Balaídos  Antonio Matéu Lahoz
# 3     Estadi Municipal de Montilivi        Juan Martínez
# 4     Estadio Ramón Sánchez Pizjuán  Alejandro Hernández
# ...                             ...                  ...
# 3035    Campo de Fútbol de Vallecas    Ricardo de Burgos
# 3036      Estadio Santiago Bernabéu         Mario Melero
# 3037                      San Mamés       Pablo González
# 3038  Estadi Municipal de Montilivi            Jesús Gil
# 3039         Estadio de la Cerámica      Javier Alberola
#
# [3040 rows x 15 columns]

# %%
data['Wk'] = data['Wk'].astype(int)

# %%
data
# Out:
#          Season  Wk  Day       Date   Time  Home Position            Home  \
# 0     2017-2018   1  Fri 2017-08-18  20:15              0         Leganes
# 1     2017-2018   1  Fri 2017-08-18  22:15              0        Valencia
# 2     2017-2018   1  Sat 2017-08-19  18:15              0      Celta Vigo
# 3     2017-2018   1  Sat 2017-08-19  20:15              0          Girona
# 4     2017-2018   1  Sat 2017-08-19  22:15              0         Sevilla
# ...         ...  ..  ...        ...    ...            ...             ...
# 3035  2024-2025  38  Sat 2025-05-24  21:00              8  Rayo Vallecano
# 3036  2024-2025  38  Sat 2025-05-24  16:15              2     Real Madrid
# 3037  2024-2025  38  Sun 2025-05-25  21:00              4   Athletic Club
# 3038  2024-2025  38  Sun 2025-05-25  14:00             15          Girona
# 3039  2024-2025  38  Sun 2025-05-25  16:15              5      Villarreal
#
#        xG Score  xG.1             Away  Away Position  Attendance  \
# 0     1.3   1–0   1.1           Alaves              0      9231.0
# 1     1.4   1–0   0.2       Las Palmas              0     35971.0
# 2     1.8   2–3   2.1    Real Sociedad              0     16961.0
# 3     2.2   2–2   0.7  Atletico Madrid              0     11511.0
# 4     2.4   1–1   1.3         Espanyol              0     30487.0
# ...   ...   ...   ...              ...            ...         ...
# 3035  2.2   0–0   0.6         Mallorca             10     13854.0
# 3036  2.6   2–0   0.8    Real Sociedad             11     73186.0
# 3037  1.2   0–3   3.5        Barcelona              1     50231.0
# 3038  0.0   0–4   2.7  Atletico Madrid              3     11546.0
# 3039  1.1   4–2   1.5          Sevilla             16     17758.0
#
#                               Venue              Referee
# 0     Estadio Municipal de Butarque         José Munuera
# 1               Estadio de Mestalla            Jesús Gil
# 2               Estadio de Balaídos  Antonio Matéu Lahoz
# 3     Estadi Municipal de Montilivi        Juan Martínez
# 4     Estadio Ramón Sánchez Pizjuán  Alejandro Hernández
# ...                             ...                  ...
# 3035    Campo de Fútbol de Vallecas    Ricardo de Burgos
# 3036      Estadio Santiago Bernabéu         Mario Melero
# 3037                      San Mamés       Pablo González
# 3038  Estadi Municipal de Montilivi            Jesús Gil
# 3039         Estadio de la Cerámica      Javier Alberola
#
# [3040 rows x 15 columns]

# %% [markdown]
# ## Writing the data to be preprocessed to csv

# %%
data.to_csv('laliga_2017_2025_matchdata.csv', index=False)
